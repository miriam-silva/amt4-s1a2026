# %% [markdown]
# <a href="https://colab.research.google.com/github/miriam-silva/amt4-s1a2026/blob/main/Aula2403_amt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=2
b=3
print('A soma é: ',a+b)
# Out:
# A soma é:  5

# %% [markdown]
# ## Segunda camada

# %%
c=4
d=5
print('A multiplicação é: ' ,c*d)
# Out:
# A multiplicação é:  20

# %% [markdown]
# # Bibliotecas e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if (delta < 0):
    return 'Número sem raiz', delta

  x1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)

  return x1, x2

# %% [markdown]
# # Testes de Função Matemática

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

  eq += equacao2grau(a, b, c)

# %%
print(eq)
# Out:
# (2.0, 1.0, 0.0, -2.3333333333333335, 1.224744871391589, -1.224744871391589, -4.212214450449026, 0.712214450449026, 'Número sem raiz', -84, 0.7403124237432849, -0.5403124237432848)
