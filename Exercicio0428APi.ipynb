# %% [markdown]
# <a href="https://colab.research.google.com/github/miriam-silva/amt4-s1a2026/blob/main/Exercicio0428APi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time

API_KEY = 'GP19727SNL1LFSUI'

symbols = {
    'netflix': 'NFLX',
    'apple': 'AAPL',
    'google': 'GOOGL',
    'amazon': 'AMZN'
}

bases = {}

for nome, symbol in symbols.items():
    url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={symbol}&apikey={API_KEY}'
    r = requests.get(url)
    data = r.json()

    bases[nome] = data

    time.sleep(12)

# %%
def criar_df(seguro_base, nome):
    if 'Global Quote' in seguro_base and seguro_base['Global Quote']:
        df = pd.DataFrame.from_dict([seguro_base['Global Quote']])
        df['empresa'] = nome
        return df
    else:
        print(f"Erro ao obter dados de {nome}: {seguro_base}")
        return pd.DataFrame()

base_alpha_netflix = criar_df(bases['netflix'], 'Netflix')
base_alpha_apple = criar_df(bases['apple'], 'Apple')
base_alpha_google = criar_df(bases['google'], 'Google')
base_alpha_amazon = criar_df(bases['amazon'], 'Amazon')

df_final = pd.concat([
    base_alpha_netflix,
    base_alpha_apple,
    base_alpha_google,
    base_alpha_amazon
], ignore_index=True)

df_final
# Out:
#   01. symbol  02. open  03. high   04. low 05. price 06. volume  \
# 0       NFLX   92.0500   92.8400   91.3000   91.3700   29707439
# 1       AAPL  266.0900  268.3600  265.0700  267.6100   41466762
# 2      GOOGL  345.9800  353.1800  342.7300  350.3400   28576887
# 3       AMZN  263.4600  264.1500  260.3400  261.1200   44906840
#
#   07. latest trading day 08. previous close 09. change 10. change percent  \
# 0             2026-04-27            92.4400    -1.0700           -1.1575%
# 1             2026-04-27           271.0600    -3.4500           -1.2728%
# 2             2026-04-27           344.4000     5.9400            1.7247%
# 3             2026-04-27           263.9900    -2.8700           -1.0872%
#
#    empresa
# 0  Netflix
# 1    Apple
# 2   Google
# 3   Amazon
